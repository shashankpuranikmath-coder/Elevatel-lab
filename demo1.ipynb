# %%
import pandas as pd
import seaborn as sns
sns.set(color_codes=True)

# %%
w=pd.read_csv('demo.csv')

# %%
w.head()
# Out:
#    Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1  05-02-2010    1643690.90             0        42.31       2.572
# 1      1  12-02-2010    1641957.44             1        38.51       2.548
# 2      1  19-02-2010    1611968.17             0        39.93       2.514
# 3      1  26-02-2010    1409727.59             0        46.63       2.561
# 4      1  05-03-2010    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment
# 0  211.096358         8.106
# 1  211.242170         8.106
# 2  211.289143         8.106
# 3  211.319643         8.106
# 4  211.350143         8.106

# %%
w.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6435 non-null   int64
#  1   Date          6435 non-null   object
#  2   Weekly_Sales  6435 non-null   float64
#  3   Holiday_Flag  6435 non-null   int64
#  4   Temperature   6435 non-null   float64
#  5   Fuel_Price    6435 non-null   float64
#  6   CPI           6435 non-null   float64
#  7   Unemployment  6435 non-null   float64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 402.3+ KB

# %%
sns.barplot(w['Store'], w['Weekly_Sales'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 sns.barplot(w['Store'], w['Weekly_Sales'])
#
# TypeError: barplot() takes from 0 to 1 positional arguments but 2 were given

# %%
sns.barplot(w['Store'], w['Date'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 sns.barplot(w['Store'], w['Date'])
#
# TypeError: barplot() takes from 0 to 1 positional arguments but 2 were given

# %%
sns.barplot(w['Store'], w['Temperature'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 sns.barplot(w['Store'], w['Temperature'])
#
# TypeError: barplot() takes from 0 to 1 positional arguments but 2 were given

# %%
sns.barplot(x=w['Store'], y=w['Weekly_Sales'])
# Out:
# <Axes: xlabel='Store', ylabel='Weekly_Sales'>

# %%
sns.distplot(w['Weekly_Sales'])
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_1708\4063960224.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(w['Weekly_Sales'])
# <Axes: xlabel='Weekly_Sales', ylabel='Density'>

# %%
sns.jointplot(x=w['Store'], y=w['Weekly_Sales'])

# %%
sns.countplot(w['Weekly_Sales'])
# Out:
# <Axes: ylabel='count'>
